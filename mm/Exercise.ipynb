# %%
#1
import numpy as np
import pandas as pd

arr = np.arange(1,9,1)
arr = arr.reshape(4,2)
arr.astype('i')

arr.dtype
# Out:
# dtype('int64')

# %%
#2
a = np.arange(100,200,10)
a = a.reshape(5,2)
a
# Out:
# array([[100, 110],
#        [120, 130],
#        [140, 150],
#        [160, 170],
#        [180, 190]])

# %%
#3
sarr = np.array([[11 ,22, 33], [44, 55, 66], [77, 88, 99]])
s =sarr[sarr[:,1].argsort()[::-1]]

print(s)
# Out:
# [[77 88 99]
#  [44 55 66]
#  [11 22 33]]

# %%
#4
sarray = np.array([[3 ,6, 9, 12], [15 ,18, 21, 24],
[27 ,30, 33, 36], [39 ,42, 45, 48], [51 ,54, 57, 60]])

for i in range(0,6):
    for j in range(0,4):
        if i%2 == 1 and j%2 == 0:
           print(sarray[i][j])
# Out:
# 15
# 21
# 39
# 45
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-45a66e61650f> in <module>
#       6     for j in range(0,4):
#       7         if i%2 == 1 and j%2 == 0:
# ----> 8            print(sarray[i][j])
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
#5
arr1 = np.array([[5, 6, 9], [21 ,18, 27]])
arr2 = np.array([[15 ,33, 24], [4 ,7, 1]])
arr = np.concatenate((arr1, arr2))

arr = np.square(arr, out=None, where=True, dtype=None)

print(arr)
# Out:
# [[  25   36   81]
#  [ 441  324  729]
#  [ 225 1089  576]
#  [  16   49    1]]

# %%
#6

df = pd.read_csv('ds_salaries.csv')
df.replace('?','0')
df.replace('NaN','0')
df.replace('n.a','0')


df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
#7
salary = df.sort_values(by = ['salary_in_usd'],  ascending=False)
salary
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 252         252       2021               EX              FT
# 97           97       2021               MI              FT
# 33           33       2020               MI              FT
# 157         157       2021               MI              FT
# 225         225       2021               EX              CT
# ..          ...        ...              ...             ...
# 179         179       2021               MI              FT
# 77           77       2021               MI              PT
# 238         238       2021               EN              FT
# 185         185       2021               MI              FT
# 176         176       2021               MI              FT
#
#                               job_title  salary salary_currency  \
# 252             Principal Data Engineer  600000             USD
# 97               Financial Data Analyst  450000             USD
# ...

# %%
max(df["salary_in_usd"])
# Out:
# 600000

# %%
#8
df.loc[1]
# Out:
# Unnamed: 0                                     1
# work_year                                   2020
# experience_level                              SE
# employment_type                               FT
# job_title             Machine Learning Scientist
# salary                                    260000
# salary_currency                              USD
# salary_in_usd                             260000
# employee_residence                            JP
# remote_ratio                                   0
# company_location                              JP
# company_size                                   S
# Name: 1, dtype: object

# %%
#9

df['salary'].value_counts()
# Out:
# 100000     18
# 80000      18
# 120000     15
# 60000      15
# 150000     14
#            ..
# 256000      1
# 39600       1
# 1335000     1
# 52500       1
# 129000      1
# Name: salary, Length: 272, dtype: int64

# %%
#11

df["job_title"].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...
